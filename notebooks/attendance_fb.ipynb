# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import regex as re

# %%
page_to_scrape = requests.get("https://en.wikipedia.org/wiki/2016_Duke_Blue_Devils_football_team")
soup = BeautifulSoup(page_to_scrape.text, "html.parser")

# %%
tables = soup.findAll("table", attrs={"class":"wikitable"})

count = 0
for table in tables:
    if count>0:
        break
    game_table = table
    count += 1

# %%
game_table
# Out:
# <table class="wikitable" style="font-size:95%"><tbody><tr><th>Date</th><th>Time</th><th>Opponent</th><th>Site</th><th>TV</th><th>Result</th><th>Attendance</th></tr><tr class="CFB-schedule-row" style="background-color:#DDFFDD"><td style="white-space:nowrap">September 3</td><td style="white-space:nowrap">6:00 p.m.</td><td style="white-space:nowrap"><a href="/wiki/2016_North_Carolina_Central_Eagles_football_team" title="2016 North Carolina Central Eagles football team">North Carolina Central</a><span class="CFB-schedule-ncgame">*</span></td><td><link href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"/><div class="hlist"><ul><li><a href="/wiki/Wallace_Wade_Stadium" title="Wallace Wade Stadium">Wallace Wade Stadium</a></li><li><a href="/wiki/Durham,_North_Carolina" title="Durham, North Carolina">Durham, NC</a></li></ul></div></td><td><a href="/wiki/ESPN3" title="ESPN3">ACCN+</a></td><td style="white-space:nowrap"><span style="display:inline-block; font-weight:bold; width:1em">W</span> 49–6</td><td style="text-align:center">35,049</td></tr>
# <tr class="CFB-schedule-row" style="background-color:#FFDDDD"><td style="white-space:nowrap">September 10</td><td style="white-space:nowrap">3:30 p.m.</td><td style="white-space:nowrap"><a href="/wiki/2016_Wake_Forest_Demon_Deacons_football_team" title="2016 Wake Forest Demon Deacons football team">Wake Forest</a></td><td><link href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"/><div class="hlist"><ul><li>Wallace Wade Stadium</li><li>Durham, NC</li></ul></div></td><td><a href="/wiki/ESPNU_College_Football" title="ESPNU College Football">ESPNU</a></td><td style="white-space:nowrap"><span style="display:inline-block; font-weight:bold; width:1em">L</span> 14–24</td><td style="text-align:center">21,077</td></tr>
# <tr class="CFB-schedule-row" style="background-color:#FFDDDD"><td style="white-space:nowrap">September 17</td><td style="white-space:nowrap">8:00 p.m.</td><td style="white-space:nowrap">at <a href="/wiki/2016_Northwestern_Wildcats_football_team" title="2016 Northwestern Wildcats football team">Northwestern</a><span class="CFB-schedule-ncgame">*</span></td><td><link href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"/><div class="hlist"><ul><li><a href="/wiki/Ryan_Field_(stadium)" title="Ryan Field (stadium)">Ryan Field</a></li><li><a href="/wiki/Evanston,_Illinois" title="Evanston, Illinois">Evanston, IL</a></li></ul></div></td><td><a href="/wiki/Big_Ten_Network" title="Big Ten Network">BTN</a></td><td style="white-space:nowrap"><span style="display:inline-block; font-weight:bold; width:1em">L</span> 13–24</td><td style="text-align:center">34,464</td></tr>
# <tr class="CFB-schedule-row" style="background-color:#DDFFDD"><td style="white-space:nowrap">September 24</td><td style="white-space:nowrap">3:30 p.m.</td><td style="white-space:nowrap">at <a href="/wiki/2016_Notre_Dame_Fighting_Irish_football_team" title="2016 Notre Dame Fighting Irish football team">Notre Dame</a><span class="CFB-schedule-ncgame">*</span></td><td><link href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"
href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"/><div class="hlist"><ul><li><a href="/wiki/Hard_Rock_Stadium" title="Hard Rock Stadium">Hard Rock Stadium</a></li><li><a href="/wiki/Miami_Gardens,_Florida" title="Miami Gardens, Florida">Miami Gardens, FL</a></li></ul></div></td><td><a href="/wiki/ESPN_College_Football" title="ESPN College Football">ESPN2</a></td><td style="white-space:nowrap"><span style="display:inline-block; font-weight:bold; width:1em">L</span> 21–40</td><td style="text-align:center">57,396</td></tr>
# <tr><td colspan="7" style="font-size:85%"><link href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"/><div class="hlist"><ul><li>*Non-conference game</li><li><sup class="CFB-schedule-hcgame"><span class="mw-default-size" typeof="mw:File"><span><img alt="dagger" class="mw-file-element" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/></span></span></sup>Homecoming</li><li>Rankings from <a href="/wiki/2016_NCAA_Division_I_FBS_football_rankings#AP_Poll" title="2016 NCAA Division I FBS football rankings">AP Poll</a> released prior to the game</li><li>All times are in <a href="/wiki/Eastern_Time_Zone" title="Eastern Time Zone">Eastern time</a></li></ul></div></td></tr></tbody></table>

# %%
game_dict = {}
game_dict["date"] = []
game_dict["time"] = []
game_dict["opponent"] = []
game_dict["site"] = []
game_dict["tv"] = []
game_dict["result"] = []
game_dict["attendance"] = []

for row in game_table.findAll("tr"):
    cells = row.findAll("td")
    
    if len(cells) == 7:

        game_dict["date"].append(cells[0].find(text=True))
        game_dict["time"].append(cells[1].find(text=True))
        game_dict["opponent"].append(cells[2].find(text=True))
        game_dict["site"].append(cells[3].find(text=True))
        game_dict["tv"].append(cells[4].find(text=True))
        game_dict["result"].append(cells[5].find(text=True))
        game_dict["attendance"].append(cells[6].find(text=True))
# Out:
# C:\Users\JaredBailey\AppData\Local\Temp\ipykernel_18588\2369437932.py:15: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   game_dict["date"].append(cells[0].find(text=True))
# C:\Users\JaredBailey\AppData\Local\Temp\ipykernel_18588\2369437932.py:16: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   game_dict["time"].append(cells[1].find(text=True))
# C:\Users\JaredBailey\AppData\Local\Temp\ipykernel_18588\2369437932.py:17: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   game_dict["opponent"].append(cells[2].find(text=True))
# C:\Users\JaredBailey\AppData\Local\Temp\ipykernel_18588\2369437932.py:18: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   game_dict["site"].append(cells[3].find(text=True))
# C:\Users\JaredBailey\AppData\Local\Temp\ipykernel_18588\2369437932.py:19: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   game_dict["tv"].append(cells[4].find(text=True))
# C:\Users\JaredBailey\AppData\Local\Temp\ipykernel_18588\2369437932.py:20: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   game_dict["result"].append(cells[5].find(text=True))
# C:\Users\JaredBailey\AppData\Local\Temp\ipykernel_18588\2369437932.py:21: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   game_dict["attendance"].append(cells[6].find(text=True))

# %%
game_dict
# Out:
# {'date': ['September 3',
#   'September 10',
#   'September 17',
#   'September 24',
#   'October 1',
#   'October 8',
#   '.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}',
#   'October 29',
#   'November 5',
#   'November 10',
#   'November 19',
#   'November 26'],
#  'time': ['6:00 p.m.',
#   '3:30 p.m.',
#   '8:00 p.m.',
#   '3:30 p.m.',
#   '12:30 p.m.',
#   '3:30 p.m.',
#   '7:00 p.m.',
#   '12:00 p.m.',
#   '3:30 p.m.',
#   '7:30 p.m.',
#   '3:00 p.m.',
#   '3:30 p.m.'],
#  'opponent': ['North Carolina Central',
#   'Wake Forest',
#   'at ',
#   'at ',
#   'Virginia',
#   'Army',
#   'at No.\xa07 ',
#   'at ',
#   'No.\xa023 ',
#   'No.\xa015 ',
#   'at ',
#   'at '],
#  'site': ['Wallace Wade Stadium',
#   'Wallace Wade Stadium',
#   'Ryan Field',
#   'Notre Dame Stadium',
#   'Wallace Wade Stadium',
#   'Wallace Wade Stadium',
#   "Papa John's Cardinal Stadium",
#   'Bobby Dodd Stadium',
#   'Wallace Wade Stadium',
#   'Wallace Wade Stadium',
#   'Heinz Field',
#   'Hard Rock Stadium'],
#  'tv': ['ACCN+',
#   'ESPNU',
#   'BTN',
#   'NBC',
#   'ACCN',
#   'ACCRSN',
#   'ESPN',
#   'ACCRSN',
#   'ESPNU',
#   'ESPN',
#   'ACCRSN',
#   'ESPN2'],
#  'result': ['W', 'L', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'W', 'L', 'L'],
#  'attendance': ['35,049',
#   '21,077',
#   '34,464',
#   '80,795',
#   '25,201',
#   '20,613',
#   '55,121',
#   '43,886',
#   '38,217',
#   '39,212',
#   '35,425',
#   '57,396']}

# %%
# loop through dictionary and make a list of column names
col_names = []
rows = []
for key, value in game_dict.items():
    col_names.append(key)
    rows.append(value)

# create dataframe of col_names
df = pd.DataFrame(columns=col_names)

# loop through lists and form rows
count = 1
for i in range(len(rows[0])):
    if count == 36:
        break
    row = []
    for j in range(len(rows)):
        row.append(rows[j][i])
    df.loc[i] = row
    count += 1

# %%
df
# Out:
#                                                  date        time  \
# 0                                         September 3   6:00 p.m.
# 1                                        September 10   3:30 p.m.
# 2                                        September 17   8:00 p.m.
# 3                                        September 24   3:30 p.m.
# 4                                           October 1  12:30 p.m.
# 5                                           October 8   3:30 p.m.
# 6   .mw-parser-output .tooltip-dotted{border-botto...   7:00 p.m.
# 7                                          October 29  12:00 p.m.
# 8                                          November 5   3:30 p.m.
# 9                                         November 10   7:30 p.m.
# 10                                        November 19   3:00 p.m.
# 11                                        November 26   3:30 p.m.
#
#                   opponent                          site      tv result  \
# 0   North Carolina Central          Wallace Wade Stadium   ACCN+      W
# 1              Wake Forest          Wallace Wade Stadium   ESPNU      L
# 2                      at                     Ryan Field     BTN      L
# 3                      at             Notre Dame Stadium     NBC      W
# 4                 Virginia          Wallace Wade Stadium    ACCN      L
# 5                     Army          Wallace Wade Stadium  ACCRSN      W
# 6                at No. 7   Papa John's Cardinal Stadium    ESPN      L
# 7                      at             Bobby Dodd Stadium  ACCRSN      L
# 8                  No. 23           Wallace Wade Stadium   ESPNU      L
# 9                  No. 15           Wallace Wade Stadium    ESPN      W
# 10                     at                    Heinz Field  ACCRSN      L
# 11                     at              Hard Rock Stadium   ESPN2      L
#
#    attendance
# 0      35,049
# 1      21,077
# 2      34,464
# 3      80,795
# 4      25,201
# 5      20,613
# 6      55,121
# 7      43,886
# 8      38,217
# 9      39,212
# 10     35,425
# 11     57,396

# %%
# take out the following characters from each column
# "*" and "\n"
df["date"] = df["date"].str.replace("*", "")
df["date"] = df["date"].str.replace("\n", "")
df["time"] = df["time"].str.replace("*", "")
df["time"] = df["time"].str.replace("\n", "")
df["opponent"] = df["opponent"].str.replace("*", "")
df["opponent"] = df["opponent"].str.replace("\n", "")
df["site"] = df["site"].str.replace("*", "")
df["site"] = df["site"].str.replace("\n", "")
df["tv"] = df["tv"].str.replace("*", "")
df["tv"] = df["tv"].str.replace("\n", "")
df["result"] = df["result"].str.replace("*", "")
df["result"] = df["result"].str.replace("\n", "")
df["attendance"] = df["attendance"].str.replace("*", "")
df["attendance"] = df["attendance"].str.replace("\n", "")

# convert each column to string
df["date"] = df["date"].astype(str)
df["time"] = df["time"].astype(str)
df["opponent"] = df["opponent"].astype(str)
df["site"] = df["site"].astype(str)
df["tv"] = df["tv"].astype(str)
df["result"] = df["result"].astype(str)
df["attendance"] = df["attendance"].astype(str)

# only use standard latin characters and numbers
df["date"] = df["date"].str.encode('ascii', 'ignore').str.decode('ascii')
df["time"] = df["time"].str.encode('ascii', 'ignore').str.decode('ascii')
df["opponent"] = df["opponent"].str.encode('ascii', 'ignore').str.decode('ascii')
df["site"] = df["site"].str.encode('ascii', 'ignore').str.decode('ascii')
df["tv"] = df["tv"].str.encode('ascii', 'ignore').str.decode('ascii')
df["result"] = df["result"].str.encode('ascii', 'ignore').str.decode('ascii')
df["attendance"] = df["attendance"].str.encode('ascii', 'ignore').str.decode('ascii')

# %%
df
# Out:
#                                                  date        time  \
# 0                                         September 3   6:00 p.m.
# 1                                        September 10   3:30 p.m.
# 2                                        September 17   8:00 p.m.
# 3                                        September 24   3:30 p.m.
# 4                                           October 1  12:30 p.m.
# 5                                           October 8   3:30 p.m.
# 6   .mw-parser-output .tooltip-dotted{border-botto...   7:00 p.m.
# 7                                          October 29  12:00 p.m.
# 8                                          November 5   3:30 p.m.
# 9                                         November 10   7:30 p.m.
# 10                                        November 19   3:00 p.m.
# 11                                        November 26   3:30 p.m.
#
#                   opponent                          site      tv result  \
# 0   North Carolina Central          Wallace Wade Stadium   ACCN+      W
# 1              Wake Forest          Wallace Wade Stadium   ESPNU      L
# 2                      at                     Ryan Field     BTN      L
# 3                      at             Notre Dame Stadium     NBC      W
# 4                 Virginia          Wallace Wade Stadium    ACCN      L
# 5                     Army          Wallace Wade Stadium  ACCRSN      W
# 6                 at No.7   Papa John's Cardinal Stadium    ESPN      L
# 7                      at             Bobby Dodd Stadium  ACCRSN      L
# 8                   No.23           Wallace Wade Stadium   ESPNU      L
# 9                   No.15           Wallace Wade Stadium    ESPN      W
# 10                     at                    Heinz Field  ACCRSN      L
# 11                     at              Hard Rock Stadium   ESPN2      L
#
#    attendance
# 0      35,049
# 1      21,077
# 2      34,464
# 3      80,795
# 4      25,201
# 5      20,613
# 6      55,121
# 7      43,886
# 8      38,217
# 9      39,212
# 10     35,425
# 11     57,396
